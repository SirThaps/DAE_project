# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:/Users/Duma/Downloads/lawyers.csv",skiprows=0)
data.head(141)
# Out:
#       ID  AGE  CTM  CLM               LVL  SDY
# 0      1   54   11   10    Senior Partner   35
# 1      2   25    1    0         Associate   10
# 2      3   30    9    8         Associate   87
# 3      4   26    3    3         Associate    8
# 4      5   28    3    5         Associate    4
# ..   ...  ...  ...  ...               ...  ...
# 136  137   47    6    4         Associate    9
# 137  138   43   10    8  Senior Associate   11
# 138  139   60    7    6    Junior Partner    7
# 139  140   34    6    7    Junior Partner    6
# 140  141   27    3    2         Associate   10
#
# [141 rows x 6 columns]

# %%
data.plot.scatter(x='CLM', y='CTM',color='hotpink')
data.plot.scatter(x='AGE', y='CTM',color='orange')
data.plot.scatter(x='LVL', y='CTM',color='red')
data.plot.scatter(x='SDY', y='CTM')

# %%
from sklearn.linear_model import LinearRegression

#initiate linear regression model
model = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()

#define predictor and response variables
X = data[["SDY"]]                           #Predictors
y = data["CTM"]                             #target

#define predictor and response variables
A = data[["SDY","CLM"]]                           #Predictors
B = data["CTM"]                             #target

#define predictor and response variables
C = data[["SDY","CLM","AGE"]]                           #Predictors
D = data["CTM"]                             #target

#define predictor and response variables
# E = data[["SDY","CLM","AGE","LVL"]]                           #Predictors
# F = data["CTM"]                             #target

#fit regression model
model.fit(X, y)
model2.fit(A, B)
model3.fit(C, D)

#calculate R-squared of regression model
r_squared = model.score(X, y)
r_squared2 = model2.score(A,B)
r_squared3 = model3.score(C,D)

#view R-squared value
print(r_squared)
print(r_squared2)
print(r_squared3)
# Out:
# 0.2831262302034645
# 0.8805931062442993
# 0.8832638456646539

# %%
sns.pairplot(data)
